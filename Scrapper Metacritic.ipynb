# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd
from tqdm.notebook import trange, tqdm
import concurrent.futures as cf
import time

# %%
def request(url):
    headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36'}
    response  = requests.get(url, headers = headers)
    return BeautifulSoup(response.text, 'html.parser')

# %%
def get_nb_pages(url) :

    soup = request(url)

    num_lp = 1
    if soup.find('div', class_='pages') != None:
        last_page = soup.find('div', class_='pages').find('li', class_='last_page').find('a').text
        num_lp = int(last_page)
    return num_lp

# %%
def get_game_reviews(url):
    url = url + '/user-reviews'
    num_lp = get_nb_pages(url)

    review_dict = {'name':[]}

    for page in tqdm(range(0,num_lp)): 

        url2 = url + '?page=' + str(page)
        soup = request(url2)

        for rv in soup.find_all('div', class_='review_content'):
            if rv.find('div', class_='name') == None:
                           break
            if rv.find('div', class_='name').find('a') == None:
                           break      
            review_dict['name'].append(rv.find('div', class_='name').find('a').text)

    return pd.DataFrame(review_dict)

# %%
def get_review_user(user):
    
    user_dict = {'name':[], 'rating':[]}
    url = 'https://www.metacritic.com/user/' + str(user)
    num_lp = get_nb_pages(url)
    for i in range(0,num_lp):
        url2 = url +'?myscore-filter=Game&page=' + str(i)
        soup = request(url2)
        for review in soup.find_all('div', class_='review_content'):
            if review.find('div', class_='product_title') == None:
                break 
            user_dict['name'].append(review.find('div', class_='product_title').find('a').text)
            user_dict['rating'].append(review.find('div', class_='review_score').find_all('div')[0].text)

    return pd.DataFrame(user_dict)

# %%
profils = {'name':[], 'games':[]}
def get_profil(user):
    profils['name'].append(user)
    t = get_review_user(user)
    profils['games'].append(t)

# %%
url = 'https://www.metacritic.com/game/playstation-4/the-witcher-3-wild-hunt'
review = get_game_reviews(url)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]

# %%
review
# Out:
#                  name
# 0           jakeman25
# 1             NeOmega
# 2             ChiLocc
# 3          RecoveryRx
# 4              taress
# ...               ...
# 2289  VeryGoodReviews
# 2290           IDDQYU
# 2291          Goji_54
# 2292        SauceBox6
# 2293          Estev0n
#
# [2294 rows x 1 columns]

# %%
# Filtre pseudos déjà présents
data = pd.read_csv("data/data.csv")
review = review.loc[~review['name'].isin(data['name'])]

# %%
review
# Out:
#                  name
# 2             ChiLocc
# 3          RecoveryRx
# 4              taress
# 5           adorian89
# 7        darthsouheil
# ...               ...
# 2283  Thosevelvetygms
# 2284      tonyhank232
# 2286       jorge7ejea
# 2290           IDDQYU
# 2293          Estev0n
#
# [1440 rows x 1 columns]

# %%
start = time.time()

with cf.ThreadPoolExecutor(max_workers=2) as executor:
    executor.map(get_profil, review.name)        
    
end = time.time()
print(end - start)
# Out:
# 1198.6308524608612

# %%
df = pd.DataFrame(columns=['name', 'title', 'rating'])

# %%
for i in tqdm(range(len(profils['name']))):
    for j in range(len(profils['games'][i])):
        df.loc[len(df)] = [profils['name'][i], profils['games'][i].name[j], profils['games'][i].rating[j]]
# Out:
#   0%|          | 0/3096 [00:00<?, ?it/s]

# %%
df
# Out:
#                  name                      title rating
# 0      osmondxboxlive  The Last of Us Remastered      4
# 1            Nataraja  The Last of Us Remastered     10
# 2             Juankal  The Last of Us Remastered     10
# 3             Juankal         Grand Theft Auto V     10
# 4              Stefke  The Last of Us Remastered     10
# ...               ...                        ...    ...
# 25223     tonyhank232                  Far Cry 4      9
# 25224      jorge7ejea   The Witcher 3: Wild Hunt      0
# 25225          IDDQYU   The Witcher 3: Wild Hunt     10
# 25226         Estev0n   The Witcher 3: Wild Hunt     10
# 25227         Estev0n             Layers of Fear      1
#
# [25228 rows x 3 columns]

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                  name                      title rating
# 0      osmondxboxlive  The Last of Us Remastered      4
# 1            Nataraja  The Last of Us Remastered     10
# 2             Juankal  The Last of Us Remastered     10
# 3             Juankal         Grand Theft Auto V     10
# 4              Stefke  The Last of Us Remastered     10
# ...               ...                        ...    ...
# 25223     tonyhank232                  Far Cry 4      9
# 25224      jorge7ejea   The Witcher 3: Wild Hunt      0
# 25225          IDDQYU   The Witcher 3: Wild Hunt     10
# 25226         Estev0n   The Witcher 3: Wild Hunt     10
# 25227         Estev0n             Layers of Fear      1
#
# [24491 rows x 3 columns]

# %%
df.to_csv('data/data.csv', mode='a', header=False, index=False)

# %%
import json
# Request to RAWG to get datas
r = []
for i in tqdm(range(1,3),desc="Extraction"):
    x = requests.get(f"https://api.rawg.io/api/games?key=62015356d5514b0c9cac8884f64d643a&page_size=40&page={i}&ordering=released")
    while(x.status_code != 200):
        print("Problème, on recommence")
        x = requests.get(f"https://api.rawg.io/api/games?key=62015356d5514b0c9cac8884f64d643a&page_size=40&page={i}&ordering=released")
    r += x.json()["results"]
# Out:
# Extraction:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
r
# Out:
# [{'id': 892902,
#   'slug': 'armored-core-vi-fires-of-rubicon',
#   'name': 'ARMORED CORE VI FIRES OF RUBICON',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/games/b59/b59f7aa35d656cb35f8fe534878ef536.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 1,
#   'added_by_status': {'toplay': 1},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 329,
#   'updated': '2022-12-10T20:47:25',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 678,
#      'image_background': 'https://media.rawg.io/media/games/dcb/dcbb67f371a9a28ea38ffd73ee0f53f3.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 1,
#      'name': 'Xbox One',
#      'slug': 'xbox-one',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 5453,
#      'image_background': 'https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 18,
#      'name': 'PlayStation 4',
#      'slug': 'playstation4',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 6536,
#      'image_background': 'https://media.rawg.io/media/games/562/562553814dd54e001a541e4ee83a591c.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 754,
#      'image_background': 'https://media.rawg.io/media/games/9f1/9f1891779cb20f44de93cef33b067e50.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 507022,
#      'image_background': 'https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 169068,
#     'image_background': 'https://media.rawg.io/media/games/f87/f87457e8347484033cb34cde6101d08d.jpg'}],
#   'stores': [{'id': 890899,
#     'store': {'id': 1,
#      'name': 'Steam',
#      'slug': 'steam',
#      'domain': 'store.steampowered.com',
#      'games_count': 69983,
#      'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'}}],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/b59/b59f7aa35d656cb35f8fe534878ef536.jpg'},
#    {'id': 3685631,
#     'image': 'https://media.rawg.io/media/screenshots/a0a/a0a387a199dd4f068c41b9ff9b67eaad.jpg'},
#    {'id': 3685632,
#     'image': 'https://media.rawg.io/media/screenshots/07a/07af4811a071a6cc0a47984e67189915.jpg'},
#    {'id': 3685633,
#     'image': 'https://media.rawg.io/media/screenshots/7f4/7f40bcd98bc68af1c891e0b535e4ad37.jpg'},
#    {'id': 3685634,
#     'image': 'https://media.rawg.io/media/screenshots/6c3/6c3b1709ee0e6d107fa71c0201e3c4a5_zVaxnHT.jpg'},
#    {'id': 3685635,
#     'image': 'https://media.rawg.io/media/screenshots/5e9/5e94d6e326cf5f80d805822c0bb8b774.jpg'},
#    {'id': 3685636,
#     'image': 'https://media.rawg.io/media/screenshots/7b4/7b494af1dc595a3db2b51020fb5f4d05.jpg'}]},
#  {'id': 892901,
#   'slug': 'immortals-of-aveum',
#   'name': 'Immortals of Aveum',
#   'released': None,
#   'tba': True,
#   'background_image': None,
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 1,
#   'added_by_status': {'toplay': 1},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 0,
#   'updated': '2022-12-10T20:37:33',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 677,
#      'image_background': 'https://media.rawg.io/media/games/6cc/6cc23249972a427f697a3d10eb57a820.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 753,
#      'image_background': 'https://media.rawg.io/media/games/456/456dea5e1c7e3cd07060c14e96612001.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 507021,
#      'image_background': 'https://media.rawg.io/media/games/7fa/7fa0b586293c5861ee32490e953a4996.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#   'genres': [{'id': 3,
#     'name': 'Adventure',
#     'slug': 'adventure',
#     'games_count': 129410,
#     'image_background': 'https://media.rawg.io/media/games/4be/4be6a6ad0364751a96229c56bf69be59.jpg'}],
#   'stores': [],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': []},
#  {'id': 892900,
#   'slug': 'after-us-2',
#   'name': 'After Us',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/games/7c4/7c4625ca5e67bd6224c044fce030a2a6.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 1,
#   'added_by_status': {'toplay': 1},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 125,
#   'updated': '2022-12-10T20:27:28',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 507020,
#      'image_background': 'https://media.rawg.io/media/games/456/456dea5e1c7e3cd07060c14e96612001.jpg'},
#     'released_at': '1900-01-01',
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 3,
#     'name': 'Adventure',
#     'slug': 'adventure',
#     'games_count': 129409,
#     'image_background': 'https://media.rawg.io/media/games/9aa/9aa42d16d425fa6f179fc9dc2f763647.jpg'},
#    {'id': 83,
#     'name': 'Platformer',
#     'slug': 'platformer',
#     'games_count': 99875,
#     'image_background': 'https://media.rawg.io/media/games/f90/f90ee1a4239247a822771c40488e68c5.jpg'}],
#   'stores': [{'id': 890898,
#     'store': {'id': 1,
#      'name': 'Steam',
#      'slug': 'steam',
#      'domain': 'store.steampowered.com',
#      'games_count': 69982,
#      'image_background': 'https://media.rawg.io/media/games/34b/34b1f1850a1c06fd971bc6ab3ac0ce0e.jpg'}},
#    {'id': 890897,
#     'store': {'id': 3,
#      'name': 'PlayStation Store',
#      'slug': 'playstation-store',
#      'domain': 'store.playstation.com',
#      'games_count': 7787,
#      'image_background': 'https://media.rawg.io/media/games/328/3283617cb7d75d67257fc58339188742.jpg'}}],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/7c4/7c4625ca5e67bd6224c044fce030a2a6.jpg'},
#    {'id': 3685625,
#     'image': 'https://media.rawg.io/media/screenshots/ba0/ba06b88b57488fca947a4600cd7b339b.jpg'},
#    {'id': 3685626,
#     'image': 'https://media.rawg.io/media/screenshots/f35/f35ddc6a1b133d597ea5d9720e9e3f9b.jpg'},
#    {'id': 3685627,
#     'image': 'https://media.rawg.io/media/screenshots/fbf/fbf424e9cadd1cd083cc08a462085fe8.jpg'},
#    {'id': 3685628,
#     'image': 'https://media.rawg.io/media/screenshots/445/44532421ec5ce47566ed6ea60dd70fc3.jpg'},
#    {'id': 3685629,
#     'image': 'https://media.rawg.io/media/screenshots/943/9432d5ec1dea7a0f6b057325e89e3419.jpg'},
#    {'id': 3685630,
#     'image': 'https://media.rawg.io/media/screenshots/a53/a53cc950f4f91a92e7311d45e8ff8c76.jpg'}]},
#  {'id': 892899,
#   'slug': 'judas-2',
#   'name': 'Judas',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/games/a07/a077e6994650e9e5d55cfe70cc9b478a.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 26,
#   'added_by_status': {'yet': 6, 'owned': 4, 'toplay': 16},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 64,
#   'updated': '2022-12-10T20:14:39',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 676,
#      'image_background': 'https://media.rawg.io/media/games/840/8408ad3811289a6a5830cae60fb0b62a.jpg'},
#     'released_at': '1900-01-01',
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 752,
#      'image_background': 'https://media.rawg.io/media/games/053/053fc543bf488349610f1ae2d0c1b51b.jpg'},
#     'released_at': '1900-01-01',
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 507019,
#      'image_background': 'https://media.rawg.io/media/games/b8c/b8c243eaa0fbac8115e0cdccac3f91dc.jpg'},
#     'released_at': '1900-01-01',
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 169067,
#     'image_background': 'https://media.rawg.io/media/games/83f/83f6f70a7c1b86cd2637b029d8b42caa.jpg'},
#    {'id': 2,
#     'name': 'Shooter',
#     'slug': 'shooter',
#     'games_count': 59434,
#     'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'},
#    {'id': 5,
#     'name': 'RPG',
#     'slug': 'role-playing-games-rpg',
#     'games_count': 51401,
#     'image_background': 'https://media.rawg.io/media/games/713/713269608dc8f2f40f5a670a14b2de94.jpg'}],
#   'stores': [{'id': 890896,
#     'store': {'id': 11,
#      'name': 'Epic Games',
#      'slug': 'epic-games',
#      'domain': 'epicgames.com',
#      'games_count': 1181,
#      'image_background': 'https://media.rawg.io/media/games/baf/baf9905270314e07e6850cffdb51df41.jpg'}},
#    {'id': 890895,
#     'store': {'id': 1,
#      'name': 'Steam',
#      'slug': 'steam',
#      'domain': 'store.steampowered.com',
#      'games_count': 69981,
#      'image_background': 'https://media.rawg.io/media/games/83f/83f6f70a7c1b86cd2637b029d8b42caa.jpg'}}],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/a07/a077e6994650e9e5d55cfe70cc9b478a.jpg'},
#    {'id': 3685618,
#     'image': 'https://media.rawg.io/media/screenshots/0ab/0abd011136b4bf70f3c0c9aaca2948a5.jpg'},
#    {'id': 3685619,
#     'image': 'https://media.rawg.io/media/screenshots/e7f/e7fb50c9ec08720254baad22cd7bdec1.jpg'},
#    {'id': 3685620,
#     'image': 'https://media.rawg.io/media/screenshots/1ad/1ad63dfd5380c0578d8902553c049ad2.jpg'},
#    {'id': 3685622,
#     'image': 'https://media.rawg.io/media/screenshots/d3a/d3ab8d30822e820c2a9c9ba97f1f953c.jpg'},
#    {'id': 3685623,
#     'image': 'https://media.rawg.io/media/screenshots/38c/38c81e632c3c62e8aea0483114be0a9e.jpg'},
#    {'id': 3685624,
#     'image': 'https://media.rawg.io/media/screenshots/5c9/5c98db882a3a3975281a5c544e12bf07.jpg'}]},
#  {'id': 892898,
#   'slug': 'remnant-2',
#   'name': 'Remnant 2',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/games/fc1/fc1094d4e7c549bb1663963fcd5ea25e.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 8,
#   'added_by_status': {'yet': 2, 'owned': 1, 'toplay': 5},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 231,
#   'updated': '2022-12-10T20:50:10',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 678,
#      'image_background': 'https://media.rawg.io/media/games/dcb/dcbb67f371a9a28ea38ffd73ee0f53f3.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 754,
#      'image_background': 'https://media.rawg.io/media/games/9f1/9f1891779cb20f44de93cef33b067e50.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 507022,
#      'image_background': 'https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 169068,
#     'image_background': 'https://media.rawg.io/media/games/f87/f87457e8347484033cb34cde6101d08d.jpg'},
#    {'id': 2,
#     'name': 'Shooter',
#     'slug': 'shooter',
#     'games_count': 59434,
#     'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'},
#    {'id': 5,
#     'name': 'RPG',
#     'slug': 'role-playing-games-rpg',
#     'games_count': 51401,
#     'image_background': 'https://media.rawg.io/media/games/713/713269608dc8f2f40f5a670a14b2de94.jpg'}],
#   'stores': [{'id': 890902,
#     'store': {'id': 3,
#      'name': 'PlayStation Store',
#      'slug': 'playstation-store',
#      'domain': 'store.playstation.com',
#      'games_count': 7788,
#      'image_background': 'https://media.rawg.io/media/games/49c/49c3dfa4ce2f6f140cc4825868e858cb.jpg'}},
#    {'id': 890901,
#     'store': {'id': 11,
#      'name': 'Epic Games',
#      'slug': 'epic-games',
#      'domain': 'epicgames.com',
#      'games_count': 1182,
#      'image_background': 'https://media.rawg.io/media/games/8d6/8d69eb6c32ed6acfd75f82d532144993.jpg'}},
#    {'id': 890900,
#     'store': {'id': 1,
#      'name': 'Steam',
#      'slug': 'steam',
#      'domain': 'store.steampowered.com',
#      'games_count': 69984,
#      'image_background': 'https://media.rawg.io/media/games/7fa/7fa0b586293c5861ee32490e953a4996.jpg'}}],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/fc1/fc1094d4e7c549bb1663963fcd5ea25e.jpg'},
#    {'id': 3685613,
#     'image': 'https://media.rawg.io/media/screenshots/021/0210417934458141019d3da70518af09.jpg'},
#    {'id': 3685614,
#     'image': 'https://media.rawg.io/media/screenshots/3b9/3b9be1dfd56308c5b059978e2612c978.jpg'},
#    {'id': 3685615,
#     'image': 'https://media.rawg.io/media/screenshots/9aa/9aaaa4a8a6c6c993ee1beb5e9a0fbb39.jpg'},
#    {'id': 3685616,
#     'image': 'https://media.rawg.io/media/screenshots/08b/08b1c3f33fcf48a19db2745d953ed238.jpg'}]},
#  {'id': 892824,
#   'slug': 'post-trauma',
#   'name': 'Post Trauma',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/screenshots/258/2581a72c0424927d89e996d5ec6880e3.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 4,
#   'added_by_status': {'toplay': 4},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 19,
#   'updated': '2022-12-09T14:04:13',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 506977,
#      'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 3,
#     'name': 'Adventure',
#     'slug': 'adventure',
#     'games_count': 129397,
#     'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'}],
#   'stores': [],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/258/2581a72c0424927d89e996d5ec6880e3.jpg'},
#    {'id': 3685471,
#     'image': 'https://media.rawg.io/media/screenshots/258/2581a72c0424927d89e996d5ec6880e3.jpg'}]},
#  {'id': 892618,
#   'slug': 'armored-core-vi',
#   'name': 'Armored Core VI',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/screenshots/270/27073d9c14f06f8a37f56c2cce36cdc7.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 9,
#   'added_by_status': {'yet': 1, 'owned': 1, 'toplay': 7},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 76,
#   'updated': '2022-12-09T12:39:54',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 673,
#      'image_background': 'https://media.rawg.io/media/games/e44/e445335e611b4ccf03af71fffcbd30a4.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 506877,
#      'image_background': 'https://media.rawg.io/media/games/021/021c4e21a1824d2526f925eff6324653.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 749,
#      'image_background': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 169021,
#     'image_background': 'https://media.rawg.io/media/games/d58/d588947d4286e7b5e0e12e1bea7d9844.jpg'}],
#   'stores': [],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/270/27073d9c14f06f8a37f56c2cce36cdc7.jpg'},
#    {'id': 3684974,
#     'image': 'https://media.rawg.io/media/screenshots/270/27073d9c14f06f8a37f56c2cce36cdc7.jpg'}]},
#  {'id': 892262,
#   'slug': 'hellboy-web-of-wyrd',
#   'name': 'Hellboy Web of Wyrd',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/screenshots/4ec/4ec5de3dbd44771ff4136f439c14985f.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 4,
#   'added_by_status': {'yet': 1, 'toplay': 3},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 0,
#   'updated': '2022-12-09T10:14:14',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 186,
#      'name': 'Xbox Series S/X',
#      'slug': 'xbox-series-x',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 672,
#      'image_background': 'https://media.rawg.io/media/games/708/7080e6c87e0825cb02888bf3c44b3889.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 748,
#      'image_background': 'https://media.rawg.io/media/games/253/2534a46f3da7fa7c315f1387515ca393.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 506659,
#      'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#    {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 168948,
#     'image_background': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg'}],
#   'stores': [{'id': 890257,
#     'store': {'id': 1,
#      'name': 'Steam',
#      'slug': 'steam',
#      'domain': 'store.steampowered.com',
#      'games_count': 69975,
#      'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'}}],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/4ec/4ec5de3dbd44771ff4136f439c14985f.jpg'},
#    {'id': 3684079,
#     'image': 'https://media.rawg.io/media/screenshots/760/76087da3ffe562825789132c6e87dfe3.jpg'},
#    {'id': 3684081,
#     'image': 'https://media.rawg.io/media/screenshots/b21/b21f58c46a3f7a754269e14bf03420d5.jpg'},
#    {'id': 3684083,
#     'image': 'https://media.rawg.io/media/screenshots/d6c/d6cf3e73b01b851c12c505e48eca9e82.jpg'},
#    {'id': 3684084,
#     'image': 'https://media.rawg.io/media/screenshots/fb4/fb401c8e7760ee003266c2cbc5618377.jpg'},
#    {'id': 3684085,
#     'image': 'https://media.rawg.io/media/screenshots/4ec/4ec5de3dbd44771ff4136f439c14985f.jpg'}]},
#  {'id': 892220,
#   'slug': 'valiant-hearts-coming-home',
#   'name': 'Valiant Hearts: Coming Home',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/screenshots/bc3/bc31b9b3f6ddfac6470185c18643c511.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 5,
#   'added_by_status': {'toplay': 5},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 124,
#   'updated': '2022-12-09T09:56:07',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 21,
#      'name': 'Android',
#      'slug': 'android',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 52699,
#      'image_background': 'https://media.rawg.io/media/games/e04/e04963f3ac4c4fa83a1dc0b9231e50db.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 3,
#      'name': 'iOS',
#      'slug': 'ios',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 75966,
#      'image_background': 'https://media.rawg.io/media/games/b6b/b6b20bfc4b34e312dbc8aac53c95a348.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 4, 'name': 'iOS', 'slug': 'ios'}},
#    {'platform': {'id': 8, 'name': 'Android', 'slug': 'android'}}],
#   'genres': [{'id': 3,
#     'name': 'Adventure',
#     'slug': 'adventure',
#     'games_count': 129331,
#     'image_background': 'https://media.rawg.io/media/games/b54/b54598d1d5cc31899f4f0a7e3122a7b0.jpg'},
#    {'id': 83,
#     'name': 'Platformer',
#     'slug': 'platformer',
#     'games_count': 99780,
#     'image_background': 'https://media.rawg.io/media/games/fc8/fc838d98c9b944e6a15176eabf40bee8.jpg'}],
#   'stores': [],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/bc3/bc31b9b3f6ddfac6470185c18643c511.jpg'},
#    {'id': 3683968,
#     'image': 'https://media.rawg.io/media/screenshots/1c9/1c93245eb691657917c211c6e53cc7e3.jpg'},
#    {'id': 3683969,
#     'image': 'https://media.rawg.io/media/screenshots/bc3/bc31b9b3f6ddfac6470185c18643c511.jpg'}]},
#  {'id': 892192,
#   'slug': 'silent-forest-hamadigames',
#   'name': 'silent forest (HamadiGames)',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/92b/92b7fc8843d3a820682e700076bfb797.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 0,
#   'updated': '2022-12-09T09:45:29',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 506604,
#      'image_background': 'https://media.rawg.io/media/games/bc0/bc06a29ceac58652b684deefe7d56099.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 83,
#     'name': 'Platformer',
#     'slug': 'platformer',
#     'games_count': 99773,
#     'image_background': 'https://media.rawg.io/media/games/f46/f466571d536f2e3ea9e815ad17177501.jpg'}],
#   'stores': [{'id': 890187,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 647164,
#      'image_background': 'https://media.rawg.io/media/games/d1f/d1f872a48286b6b751670817d5c1e1be.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 45,
#     'name': '2D',
#     'slug': '2d',
#     'language': 'eng',
#     'games_count': 185590,
#     'image_background': 'https://media.rawg.io/media/games/1f4/1f47a270b8f241e4676b14d39ec620f7.jpg'},
#    {'id': 122,
#     'name': 'Pixel Graphics',
#     'slug': 'pixel-graphics',
#     'language': 'eng',
#     'games_count': 87288,
#     'image_background': 'https://media.rawg.io/media/games/f62/f62eb0901c7017776e0a5c6a94f979d5.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/92b/92b7fc8843d3a820682e700076bfb797.jpg'},
#    {'id': 3683902,
#     'image': 'https://media.rawg.io/media/screenshots/92b/92b7fc8843d3a820682e700076bfb797.jpg'}]},
#  {'id': 891532,
#   'slug': 'death-stranding-2',
#   'name': 'Death Stranding 2',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/games/b85/b85bc300d42588af66fb516b7563f74f.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 25,
#   'added_by_status': {'yet': 4, 'toplay': 21},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 309,
#   'updated': '2022-12-09T07:59:50',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 187,
#      'name': 'PlayStation 5',
#      'slug': 'playstation5',
#      'image': None,
#      'year_end': None,
#      'year_start': 2020,
#      'games_count': 747,
#      'image_background': 'https://media.rawg.io/media/games/739/73990e3ec9f43a9e8ecafe207fa4f368.jpg'},
#     'released_at': '1900-01-01',
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 2,
#      'name': 'PlayStation',
#      'slug': 'playstation'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 168917,
#     'image_background': 'https://media.rawg.io/media/games/310/3106b0e012271c5ffb16497b070be739.jpg'},
#    {'id': 3,
#     'name': 'Adventure',
#     'slug': 'adventure',
#     'games_count': 129290,
#     'image_background': 'https://media.rawg.io/media/games/26d/26d4437715bee60138dab4a7c8c59c92.jpg'}],
#   'stores': [],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/b85/b85bc300d42588af66fb516b7563f74f.jpg'},
#    {'id': 3683287,
#     'image': 'https://media.rawg.io/media/screenshots/7a9/7a97a649fde5f258651ae5e69abf0ed0.jpg'},
#    {'id': 3683289,
#     'image': 'https://media.rawg.io/media/screenshots/372/372b0916c1ce240a4406373c120abd8f.jpg'},
#    {'id': 3683292,
#     'image': 'https://media.rawg.io/media/screenshots/9c4/9c4d0e73de232433f8b977c39ca65d45.jpg'},
#    {'id': 3683296,
#     'image': 'https://media.rawg.io/media/screenshots/a25/a25a14bc153866bd1dc9f776426c7b5b.jpg'},
#    {'id': 3683300,
#     'image': 'https://media.rawg.io/media/screenshots/8a8/8a87fa3c9a671416715d9ba29789cd7f.jpg'},
#    {'id': 3683301,
#     'image': 'https://media.rawg.io/media/screenshots/901/901efd17e514cede763eeb9837a80614.jpg'}]},
#  {'id': 891246,
#   'slug': 'baldurs-pathfinder-bundle',
#   'name': "Baldur's Pathfinder Bundle",
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/468/4687f9adeeed88497f0ab040366d4ebf.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 591,
#   'updated': '2022-12-09T03:16:08',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 506008,
#      'image_background': 'https://media.rawg.io/media/games/fc1/fc1307a2774506b5bd65d7e8424664a7.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [],
#   'stores': [{'id': 889237,
#     'store': {'id': 5,
#      'name': 'GOG',
#      'slug': 'gog',
#      'domain': 'gog.com',
#      'games_count': 4610,
#      'image_background': 'https://media.rawg.io/media/games/26d/26d4437715bee60138dab4a7c8c59c92.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 468,
#     'name': 'role-playing',
#     'slug': 'role-playing',
#     'language': 'eng',
#     'games_count': 1404,
#     'image_background': 'https://media.rawg.io/media/games/9f1/9f1891779cb20f44de93cef33b067e50.jpg'},
#    {'id': 70,
#     'name': 'War',
#     'slug': 'war',
#     'language': 'eng',
#     'games_count': 8450,
#     'image_background': 'https://media.rawg.io/media/games/8ee/8eed88e297441ef9202b5d1d35d7d86f.jpg'},
#    {'id': 981,
#     'name': 'battle',
#     'slug': 'battle',
#     'language': 'eng',
#     'games_count': 10393,
#     'image_background': 'https://media.rawg.io/media/screenshots/7f8/7f8b58994fc420fefaa5fb9992335a11.jpg'},
#    {'id': 625,
#     'name': 'party',
#     'slug': 'party',
#     'language': 'eng',
#     'games_count': 3944,
#     'image_background': 'https://media.rawg.io/media/games/d11/d11470677a829e34562e95a4002c2c7f.jpg'},
#    {'id': 1309,
#     'name': 'hero',
#     'slug': 'hero',
#     'language': 'eng',
#     'games_count': 4716,
#     'image_background': 'https://media.rawg.io/media/games/d56/d564ee964eb3c17892b3b35dd607f836.jpg'},
#    {'id': 2326,
#     'name': 'explore',
#     'slug': 'explore',
#     'language': 'eng',
#     'games_count': 3184,
#     'image_background': 'https://media.rawg.io/media/games/739/73990e3ec9f43a9e8ecafe207fa4f368.jpg'},
#    {'id': 878,
#     'name': 'sword',
#     'slug': 'sword',
#     'language': 'eng',
#     'games_count': 1373,
#     'image_background': 'https://media.rawg.io/media/screenshots/a72/a7263e0ccaf879a00296db0d6d91c854.jpg'},
#    {'id': 2232,
#     'name': 'journey',
#     'slug': 'journey',
#     'language': 'eng',
#     'games_count': 1652,
#     'image_background': 'https://media.rawg.io/media/games/a70/a70712d9ffd26d5be4690745bf7d34d7.jpg'},
#    {'id': 5641,
#     'name': 'bundle',
#     'slug': 'bundle',
#     'language': 'eng',
#     'games_count': 420,
#     'image_background': 'https://media.rawg.io/media/games/641/6410d62faa02aa2794a323b752dc9084.jpg'},
#    {'id': 3748,
#     'name': 'terror',
#     'slug': 'terror',
#     'language': 'eng',
#     'games_count': 727,
#     'image_background': 'https://media.rawg.io/media/screenshots/f4d/f4d8c1733f477ddf655d14eda4162a69.jpg'},
#    {'id': 9081,
#     'name': 'search',
#     'slug': 'search',
#     'language': 'eng',
#     'games_count': 443,
#     'image_background': 'https://media.rawg.io/media/screenshots/873/873259cdc142b7ed217cdbaae893e58f.jpg'},
#    {'id': 4027,
#     'name': 'travel',
#     'slug': 'travel',
#     'language': 'eng',
#     'games_count': 684,
#     'image_background': 'https://media.rawg.io/media/screenshots/fa5/fa547d8709e5eeb249c6783e47801d1e.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/468/4687f9adeeed88497f0ab040366d4ebf.jpg'},
#    {'id': 3681441,
#     'image': 'https://media.rawg.io/media/screenshots/4a6/4a636dffcc07661a0e469577a8d2c791.jpg'},
#    {'id': 3681442,
#     'image': 'https://media.rawg.io/media/screenshots/e92/e92b9691f8b29c936352e66c4f17c23a.jpg'},
#    {'id': 3681443,
#     'image': 'https://media.rawg.io/media/screenshots/24d/24d7b196b1bfe4297c70c48a5471a1c0.jpg'},
#    {'id': 3681444,
#     'image': 'https://media.rawg.io/media/screenshots/736/736a27e7621433f430ba07c46e230306.jpg'},
#    {'id': 3681445,
#     'image': 'https://media.rawg.io/media/screenshots/ccb/ccb70147cd88da537819de95575a1aec.jpg'},
#    {'id': 3681446,
#     'image': 'https://media.rawg.io/media/screenshots/d50/d501286f357b91a6508dd97b328a0580.jpg'}]},
#  {'id': 891238,
#   'slug': 'hades-ii',
#   'name': 'Hades II',
#   'released': None,
#   'tba': True,
#   'background_image': 'https://media.rawg.io/media/games/8fd/8fd2e8317849fd265ad8781c324d4ec2.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 26,
#   'added_by_status': {'yet': 5, 'toplay': 21},
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 288,
#   'updated': '2022-12-10T11:24:29',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 507019,
#      'image_background': 'https://media.rawg.io/media/games/b8c/b8c243eaa0fbac8115e0cdccac3f91dc.jpg'},
#     'released_at': '1900-01-01',
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 3,
#     'name': 'Adventure',
#     'slug': 'adventure',
#     'games_count': 129408,
#     'image_background': 'https://media.rawg.io/media/games/34b/34b1f1850a1c06fd971bc6ab3ac0ce0e.jpg'}],
#   'stores': [{'id': 889222,
#     'store': {'id': 1,
#      'name': 'Steam',
#      'slug': 'steam',
#      'domain': 'store.steampowered.com',
#      'games_count': 69979,
#      'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'}},
#    {'id': 889221,
#     'store': {'id': 11,
#      'name': 'Epic Games',
#      'slug': 'epic-games',
#      'domain': 'epicgames.com',
#      'games_count': 1180,
#      'image_background': 'https://media.rawg.io/media/games/951/951572a3dd1e42544bd39a5d5b42d234.jpg'}}],
#   'clip': None,
#   'tags': [],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/games/8fd/8fd2e8317849fd265ad8781c324d4ec2.jpg'},
#    {'id': 3681385,
#     'image': 'https://media.rawg.io/media/screenshots/59e/59e9ba1215b11e43ad64f363bfb7f65b.jpg'},
#    {'id': 3681386,
#     'image': 'https://media.rawg.io/media/screenshots/e93/e93aa58a1bf6f628507121a206ef856d.jpg'},
#    {'id': 3681387,
#     'image': 'https://media.rawg.io/media/screenshots/f2a/f2ad5b935bec0757defcbd1245182971.jpg'},
#    {'id': 3681389,
#     'image': 'https://media.rawg.io/media/screenshots/12d/12d0e3888fde20cb974e2951fad3d4f6.jpg'},
#    {'id': 3681392,
#     'image': 'https://media.rawg.io/media/screenshots/971/971f056ee50927f331f880271b0ab414.jpg'},
#    {'id': 3681395,
#     'image': 'https://media.rawg.io/media/screenshots/565/565801fac627e1d6828fe56ea172d5ff.jpg'}]},
#  {'id': 891145,
#   'slug': 'shadelight',
#   'name': 'Shadelight',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/2d2/2d28d1ef3474999155e6c3afe0d46af1.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 137,
#   'updated': '2022-12-05T16:44:41',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 505927,
#      'image_background': 'https://media.rawg.io/media/games/49c/49c3dfa4ce2f6f140cc4825868e858cb.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 4,
#     'name': 'Action',
#     'slug': 'action',
#     'games_count': 168792,
#     'image_background': 'https://media.rawg.io/media/games/7cf/7cfc9220b401b7a300e409e539c9afd5.jpg'}],
#   'stores': [{'id': 889130,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 646185,
#      'image_background': 'https://media.rawg.io/media/screenshots/6fe/6fe228662a253cd929cc78a103541ee0.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 8,
#     'name': 'First-Person',
#     'slug': 'first-person',
#     'language': 'eng',
#     'games_count': 26475,
#     'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'},
#    {'id': 16,
#     'name': 'Horror',
#     'slug': 'horror',
#     'language': 'eng',
#     'games_count': 40322,
#     'image_background': 'https://media.rawg.io/media/games/b54/b54598d1d5cc31899f4f0a7e3122a7b0.jpg'},
#    {'id': 41,
#     'name': 'Dark',
#     'slug': 'dark',
#     'language': 'eng',
#     'games_count': 13037,
#     'image_background': 'https://media.rawg.io/media/games/6a2/6a2e48933245e2cd3c92248c75c925e1.jpg'},
#    {'id': 571,
#     'name': '3D',
#     'slug': '3d',
#     'language': 'eng',
#     'games_count': 73964,
#     'image_background': 'https://media.rawg.io/media/screenshots/9d1/9d12fe709e4bc87166b1cdb2101fa91b.jpg'},
#    {'id': 832,
#     'name': 'Halloween',
#     'slug': 'halloween',
#     'language': 'eng',
#     'games_count': 3495,
#     'image_background': 'https://media.rawg.io/media/screenshots/33c/33c8f72532b66877a5a8fb9c896b8ac6_yWACeYj.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/2d2/2d28d1ef3474999155e6c3afe0d46af1.jpg'},
#    {'id': 3680763,
#     'image': 'https://media.rawg.io/media/screenshots/129/12909bca1691c0cc87e4ecbc0ea1ab54.jpg'},
#    {'id': 3680764,
#     'image': 'https://media.rawg.io/media/screenshots/431/431c432958425b524f2769954d755021.jpg'},
#    {'id': 3680765,
#     'image': 'https://media.rawg.io/media/screenshots/170/17099be534fe9caf515a3fb0bab7dba4.jpg'},
#    {'id': 3680766,
#     'image': 'https://media.rawg.io/media/screenshots/2d2/2d28d1ef3474999155e6c3afe0d46af1.jpg'}]},
#  {'id': 891144,
#   'slug': 'ekphrasis',
#   'name': 'Ekphrasis',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/23f/23f09252b787d99ca94cb0286ab50cb1.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 51,
#   'updated': '2022-12-05T16:44:09',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 505927,
#      'image_background': 'https://media.rawg.io/media/games/49c/49c3dfa4ce2f6f140cc4825868e858cb.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 7,
#     'name': 'Puzzle',
#     'slug': 'puzzle',
#     'games_count': 95379,
#     'image_background': 'https://media.rawg.io/media/games/1fb/1fb1c5f7a71d771f440b27ce7f71e7eb.jpg'}],
#   'stores': [{'id': 889129,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 646185,
#      'image_background': 'https://media.rawg.io/media/screenshots/6fe/6fe228662a253cd929cc78a103541ee0.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 31,
#     'name': 'Singleplayer',
#     'slug': 'singleplayer',
#     'language': 'eng',
#     'games_count': 194483,
#     'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#    {'id': 118,
#     'name': 'Story Rich',
#     'slug': 'story-rich',
#     'language': 'eng',
#     'games_count': 16959,
#     'image_background': 'https://media.rawg.io/media/games/490/49016e06ae2103881ff6373248843069.jpg'},
#    {'id': 45,
#     'name': '2D',
#     'slug': '2d',
#     'language': 'eng',
#     'games_count': 185374,
#     'image_background': 'https://media.rawg.io/media/games/f3e/f3eec35c6218dcfd93a537751e6bfa61.jpg'},
#    {'id': 32,
#     'name': 'Sci-fi',
#     'slug': 'sci-fi',
#     'language': 'eng',
#     'games_count': 16336,
#     'image_background': 'https://media.rawg.io/media/games/b72/b7233d5d5b1e75e86bb860ccc7aeca85.jpg'},
#    {'id': 141,
#     'name': 'Point & Click',
#     'slug': 'point-click',
#     'language': 'eng',
#     'games_count': 11142,
#     'image_background': 'https://media.rawg.io/media/games/6d3/6d33014a4ed48a19c30a77ead5a0f62e.jpg'},
#    {'id': 583,
#     'name': 'Narrative',
#     'slug': 'narrative',
#     'language': 'eng',
#     'games_count': 8247,
#     'image_background': 'https://media.rawg.io/media/games/348/3485bd1bfce1d9025cd5bd8f9fc8a356.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/23f/23f09252b787d99ca94cb0286ab50cb1.jpg'},
#    {'id': 3680758,
#     'image': 'https://media.rawg.io/media/screenshots/a21/a2124c23c3d896d48fc945a20fe3505f.jpg'},
#    {'id': 3680759,
#     'image': 'https://media.rawg.io/media/screenshots/2c0/2c0faf75f0071e86bf7546ee8a47eeb6.jpg'},
#    {'id': 3680760,
#     'image': 'https://media.rawg.io/media/screenshots/5e2/5e283c1e3437d4c8720125b78075c6d7.jpg'},
#    {'id': 3680761,
#     'image': 'https://media.rawg.io/media/screenshots/8a6/8a6864facf2551ed3062186051521158.jpg'},
#    {'id': 3680762,
#     'image': 'https://media.rawg.io/media/screenshots/23f/23f09252b787d99ca94cb0286ab50cb1.jpg'}]},
#  {'id': 891130,
#   'slug': 'destiny-of-jonathan-maze-of-salala',
#   'name': 'Destiny of Jonathan: Maze of Salala',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/261/26158c63413693bf786ea2c14ce55755.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 0,
#   'updated': '2022-12-05T16:37:59',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 6,
#      'name': 'Linux',
#      'slug': 'linux',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 75104,
#      'image_background': 'https://media.rawg.io/media/games/73e/73eecb8909e0c39fb246f457b5d6cbbe.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 6,
#      'name': 'Linux',
#      'slug': 'linux'}}],
#   'genres': [{'id': 5,
#     'name': 'RPG',
#     'slug': 'role-playing-games-rpg',
#     'games_count': 51311,
#     'image_background': 'https://media.rawg.io/media/games/21c/21cc15d233117c6809ec86870559e105.jpg'}],
#   'stores': [{'id': 889115,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 646185,
#      'image_background': 'https://media.rawg.io/media/screenshots/6fe/6fe228662a253cd929cc78a103541ee0.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 31,
#     'name': 'Singleplayer',
#     'slug': 'singleplayer',
#     'language': 'eng',
#     'games_count': 194483,
#     'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#    {'id': 571,
#     'name': '3D',
#     'slug': '3d',
#     'language': 'eng',
#     'games_count': 73964,
#     'image_background': 'https://media.rawg.io/media/screenshots/9d1/9d12fe709e4bc87166b1cdb2101fa91b.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/261/26158c63413693bf786ea2c14ce55755.jpg'},
#    {'id': 3680724,
#     'image': 'https://media.rawg.io/media/screenshots/8b1/8b1039d08b48486b0688f4de31292c9b.jpg'},
#    {'id': 3680725,
#     'image': 'https://media.rawg.io/media/screenshots/c39/c39053be9068950c8a561ea2fc8e0852.jpg'},
#    {'id': 3680726,
#     'image': 'https://media.rawg.io/media/screenshots/261/26158c63413693bf786ea2c14ce55755.jpg'}]},
#  {'id': 891122,
#   'slug': 'illuminaria-itch',
#   'name': 'Illuminaria (itch)',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/5d2/5d2fe677790c516c2c541d59dfec5af9.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
# ...
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [],
#   'stores': [{'id': 872297,
#     'store': {'id': 5,
#      'name': 'GOG',
#      'slug': 'gog',
#      'domain': 'gog.com',
#      'games_count': 4585,
#      'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 25,
#     'name': 'Space',
#     'slug': 'space',
#     'language': 'eng',
#     'games_count': 40768,
#     'image_background': 'https://media.rawg.io/media/games/a6c/a6ccd34125c594abf1a9c9821b9a715d.jpg'},
#    {'id': 1709,
#     'name': 'work',
#     'slug': 'work',
#     'language': 'eng',
#     'games_count': 9076,
#     'image_background': 'https://media.rawg.io/media/games/6d3/6d33014a4ed48a19c30a77ead5a0f62e.jpg'},
#    {'id': 275,
#     'name': 'Movie',
#     'slug': 'movie',
#     'language': 'eng',
#     'games_count': 1002,
#     'image_background': 'https://media.rawg.io/media/games/b4d/b4d2004ef9afea5c14317fe94bcc8996.jpg'},
#    {'id': 1497,
#     'name': 'car',
#     'slug': 'car',
#     'language': 'eng',
#     'games_count': 7409,
#     'image_background': 'https://media.rawg.io/media/screenshots/d52/d52c7807e12159c1ef2b956c38f77187.jpg'},
#    {'id': 740,
#     'name': 'demo',
#     'slug': 'demo',
#     'language': 'eng',
#     'games_count': 4477,
#     'image_background': 'https://media.rawg.io/media/screenshots/fb4/fb4ed59de5364d1a6f33cd1b2de650ea.jpg'},
#    {'id': 5506,
#     'name': 'wizards',
#     'slug': 'wizards',
#     'language': 'eng',
#     'games_count': 1018,
#     'image_background': 'https://media.rawg.io/media/screenshots/206/206eead729a76c4d3b61a5dacd0159f1_sakosOY.jpg'},
#    {'id': 3076,
#     'name': 'rush',
#     'slug': 'rush',
#     'language': 'eng',
#     'games_count': 322,
#     'image_background': 'https://media.rawg.io/media/screenshots/8f7/8f7a18503dc262d27cf4b3f243430cf4_RSUgUuG.jpg'},
#    {'id': 9659,
#     'name': 'rewind',
#     'slug': 'rewind',
#     'language': 'eng',
#     'games_count': 335,
#     'image_background': 'https://media.rawg.io/media/screenshots/9b6/9b6850ae0aa6478e4c107c25e03efa25.jpg'},
#    {'id': 4166,
#     'name': 'timing',
#     'slug': 'timing',
#     'language': 'eng',
#     'games_count': 173,
#     'image_background': 'https://media.rawg.io/media/screenshots/32a/32a393bad33fa0dc26a5880859085be4.jpg'},
#    {'id': 7231,
#     'name': 'roll',
#     'slug': 'roll',
#     'language': 'eng',
#     'games_count': 458,
#     'image_background': 'https://media.rawg.io/media/screenshots/77c/77cfc150ba4389056b73dd91fd6e404f.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/a64/a644c31c036f169b49e938e1bdb791c9.jpg'},
#    {'id': 3633772,
#     'image': 'https://media.rawg.io/media/screenshots/f46/f4603bea573b208c8361ff1a1324c4ec.jpg'},
#    {'id': 3633773,
#     'image': 'https://media.rawg.io/media/screenshots/c7c/c7cbfefc7fff9914da00725448a072c6.jpg'},
#    {'id': 3633774,
#     'image': 'https://media.rawg.io/media/screenshots/b56/b56ddd17cb34954e9d1de48c6a0e9f79.jpg'},
#    {'id': 3633775,
#     'image': 'https://media.rawg.io/media/screenshots/d04/d044f6a35f0a3ca2e3fad7e5262168a5.jpg'},
#    {'id': 3633776,
#     'image': 'https://media.rawg.io/media/screenshots/c35/c35f14c1d61d1016ef5367946ad8280c.jpg'},
#    {'id': 3633777,
#     'image': 'https://media.rawg.io/media/screenshots/a64/a644c31c036f169b49e938e1bdb791c9.jpg'}]},
#  {'id': 874312,
#   'slug': 'stella-pastoris-itch',
#   'name': 'Stella Pastoris (itch)',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/b51/b5186febbdea427e4b155a94dcd3d4f3.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 140,
#   'updated': '2022-10-31T13:44:20',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 5,
#      'name': 'macOS',
#      'slug': 'macos',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 101428,
#      'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 503847,
#      'image_background': 'https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#   'genres': [],
#   'stores': [{'id': 871996,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 643045,
#      'image_background': 'https://media.rawg.io/media/games/177/1775aacedb915b0e0880476530dc87b4.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 16,
#     'name': 'Horror',
#     'slug': 'horror',
#     'language': 'eng',
#     'games_count': 40091,
#     'image_background': 'https://media.rawg.io/media/games/da1/da1b267764d77221f07a4386b6548e5a.jpg'},
#    {'id': 74,
#     'name': 'Retro',
#     'slug': 'retro',
#     'language': 'eng',
#     'games_count': 37435,
#     'image_background': 'https://media.rawg.io/media/games/ffe/ffed87105b14f5beff72ff44a7793fd5.jpg'},
#    {'id': 25,
#     'name': 'Space',
#     'slug': 'space',
#     'language': 'eng',
#     'games_count': 40768,
#     'image_background': 'https://media.rawg.io/media/games/a6c/a6ccd34125c594abf1a9c9821b9a715d.jpg'},
#    {'id': 213,
#     'name': 'City Builder',
#     'slug': 'city-builder',
#     'language': 'eng',
#     'games_count': 2022,
#     'image_background': 'https://media.rawg.io/media/games/725/725d08c4174c129ce5275c43cd0347c6.jpg'},
#    {'id': 714,
#     'name': '1-bit',
#     'slug': '1-bit',
#     'language': 'eng',
#     'games_count': 1883,
#     'image_background': 'https://media.rawg.io/media/screenshots/d7c/d7c25134b9acfad47abacd9fe4721413.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/b51/b5186febbdea427e4b155a94dcd3d4f3.jpg'},
#    {'id': 3632286,
#     'image': 'https://media.rawg.io/media/screenshots/e62/e6285b9451dbdaf67c91848181eff56c.jpg'},
#    {'id': 3632287,
#     'image': 'https://media.rawg.io/media/screenshots/036/036ae32be0f80b52674c472b4d31d323.jpg'},
#    {'id': 3632288,
#     'image': 'https://media.rawg.io/media/screenshots/1e9/1e9abdda0b1b4e9e77bdab25d9adbad0.jpg'},
#    {'id': 3632289,
#     'image': 'https://media.rawg.io/media/screenshots/d47/d47e741f1c13fb3009991dad839dd961.jpg'},
#    {'id': 3632290,
#     'image': 'https://media.rawg.io/media/screenshots/b51/b5186febbdea427e4b155a94dcd3d4f3.jpg'}]},
#  {'id': 874279,
#   'slug': 'strawb',
#   'name': 'Strawb',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/3ce/3ce7a33e7c864add58016a49ca52e633.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 95,
#   'updated': '2022-10-31T13:29:14',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 171,
#      'name': 'Web',
#      'slug': 'web',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 248604,
#      'image_background': 'https://media.rawg.io/media/screenshots/6aa/6aa8cfccfa7f8d7acbe1a6e24dfb45dd.jpeg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None},
#    {'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 503847,
#      'image_background': 'https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#    {'platform': {'id': 14, 'name': 'Web', 'slug': 'web'}}],
#   'genres': [{'id': 7,
#     'name': 'Puzzle',
#     'slug': 'puzzle',
#     'games_count': 95053,
#     'image_background': 'https://media.rawg.io/media/games/2e1/2e187b31e5cee21c110bd16798d75fab.jpg'}],
#   'stores': [{'id': 871963,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 643045,
#      'image_background': 'https://media.rawg.io/media/games/177/1775aacedb915b0e0880476530dc87b4.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 45,
#     'name': '2D',
#     'slug': '2d',
#     'language': 'eng',
#     'games_count': 184539,
#     'image_background': 'https://media.rawg.io/media/games/04a/04a7e7e185fb51493bdcbe1693a8b3dc.jpg'},
#    {'id': 83,
#     'name': 'Puzzle-Platformer',
#     'slug': 'puzzle-platformer',
#     'language': 'eng',
#     'games_count': 9517,
#     'image_background': 'https://media.rawg.io/media/games/d5a/d5a24f9f71315427fa6e966fdd98dfa6.jpg'},
#    {'id': 607,
#     'name': 'Unity',
#     'slug': 'unity',
#     'language': 'eng',
#     'games_count': 68468,
#     'image_background': 'https://media.rawg.io/media/screenshots/d1f/d1f51898c2aee5731b2e3ab2d4f1a56c.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/3ce/3ce7a33e7c864add58016a49ca52e633.jpg'},
#    {'id': 3632203,
#     'image': 'https://media.rawg.io/media/screenshots/bdd/bddb9c230e46bfdb50be3fc0f408e0c3.jpg'},
#    {'id': 3632204,
#     'image': 'https://media.rawg.io/media/screenshots/ed9/ed975de6b3beab205d8186bdbb52bc6f.jpg'},
#    {'id': 3632205,
#     'image': 'https://media.rawg.io/media/screenshots/abb/abb6f31ecd325db14ebf8ceda62e77a6.jpg'},
#    {'id': 3632206,
#     'image': 'https://media.rawg.io/media/screenshots/e43/e43428a98a68ecadaba4133496cfd02b.jpg'},
#    {'id': 3632207,
#     'image': 'https://media.rawg.io/media/screenshots/3ce/3ce7a33e7c864add58016a49ca52e633.jpg'}]},
#  {'id': 873843,
#   'slug': 'connect-itch-logicalbyte',
#   'name': 'Connect (itch) (LogicalByte)',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/b64/b648838207d15e1aa487e714101311e1.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 53,
#   'updated': '2022-10-31T10:28:41',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 503847,
#      'image_background': 'https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [{'id': 7,
#     'name': 'Puzzle',
#     'slug': 'puzzle',
#     'games_count': 95053,
#     'image_background': 'https://media.rawg.io/media/games/2e1/2e187b31e5cee21c110bd16798d75fab.jpg'}],
#   'stores': [{'id': 871529,
#     'store': {'id': 9,
#      'name': 'itch.io',
#      'slug': 'itch',
#      'domain': 'itch.io',
#      'games_count': 643045,
#      'image_background': 'https://media.rawg.io/media/games/177/1775aacedb915b0e0880476530dc87b4.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 7,
#     'name': 'Multiplayer',
#     'slug': 'multiplayer',
#     'language': 'eng',
#     'games_count': 34039,
#     'image_background': 'https://media.rawg.io/media/games/b7b/b7b8381707152afc7d91f5d95de70e39.jpg'},
#    {'id': 74,
#     'name': 'Retro',
#     'slug': 'retro',
#     'language': 'eng',
#     'games_count': 37435,
#     'image_background': 'https://media.rawg.io/media/games/ffe/ffed87105b14f5beff72ff44a7793fd5.jpg'},
#    {'id': 855,
#     'name': 'amiga',
#     'slug': 'amiga',
#     'language': 'eng',
#     'games_count': 214,
#     'image_background': 'https://media.rawg.io/media/screenshots/2ec/2ec7fa9978ce483e2d879c9a425936ef.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/b64/b648838207d15e1aa487e714101311e1.jpg'},
#    {'id': 3631107,
#     'image': 'https://media.rawg.io/media/screenshots/384/38483913d5c9cdc9f832ef29ba4370ad.jpg'},
#    {'id': 3631108,
#     'image': 'https://media.rawg.io/media/screenshots/3ae/3ae8386366095278473ea177f8c457ed.jpg'},
#    {'id': 3631109,
#     'image': 'https://media.rawg.io/media/screenshots/b64/b648838207d15e1aa487e714101311e1.jpg'}]},
#  {'id': 872842,
#   'slug': 'r-type-tactics-i-ii-cosmos',
#   'name': 'R-Type Tactics I • II Cosmos',
#   'released': None,
#   'tba': False,
#   'background_image': 'https://media.rawg.io/media/screenshots/df7/df77682629ccca6577917c176152d65d.jpg',
#   'rating': 0.0,
#   'rating_top': 0,
#   'ratings': [],
#   'ratings_count': 0,
#   'reviews_text_count': 0,
#   'added': 0,
#   'added_by_status': None,
#   'metacritic': None,
#   'playtime': 0,
#   'suggestions_count': 225,
#   'updated': '2022-10-31T03:45:18',
#   'user_game': None,
#   'reviews_count': 0,
#   'community_rating': 0,
#   'saturated_color': '0f0f0f',
#   'dominant_color': '0f0f0f',
#   'platforms': [{'platform': {'id': 4,
#      'name': 'PC',
#      'slug': 'pc',
#      'image': None,
#      'year_end': None,
#      'year_start': None,
#      'games_count': 503847,
#      'image_background': 'https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg'},
#     'released_at': None,
#     'requirements_en': None,
#     'requirements_ru': None}],
#   'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#   'genres': [],
#   'stores': [{'id': 870525,
#     'store': {'id': 5,
#      'name': 'GOG',
#      'slug': 'gog',
#      'domain': 'gog.com',
#      'games_count': 4585,
#      'image_background': 'https://media.rawg.io/media/games/942/9424d6bb763dc38d9378b488603c87fa.jpg'}}],
#   'clip': None,
#   'tags': [{'id': 413,
#     'name': 'online',
#     'slug': 'online',
#     'language': 'eng',
#     'games_count': 6495,
#     'image_background': 'https://media.rawg.io/media/games/431/4317e294e88e4c9d77327693b15f499a.jpg'},
#    {'id': 1626,
#     'name': 'collection',
#     'slug': 'collection',
#     'language': 'eng',
#     'games_count': 3566,
#     'image_background': 'https://media.rawg.io/media/screenshots/97a/97ab26a9d092783e68190dc686916b0b.jpg'},
#    {'id': 2821,
#     'name': 'tactics',
#     'slug': 'tactics',
#     'language': 'eng',
#     'games_count': 261,
#     'image_background': 'https://media.rawg.io/media/screenshots/f12/f126454c5179e93832ca4c05a85876fc.jpg'},
#    {'id': 1472,
#     'name': 'competition',
#     'slug': 'competition',
#     'language': 'eng',
#     'games_count': 531,
#     'image_background': 'https://media.rawg.io/media/screenshots/d98/d9881f56175a5ade1259e680afbebf19_7GEuC3R.jpg'}],
#   'esrb_rating': None,
#   'short_screenshots': [{'id': -1,
#     'image': 'https://media.rawg.io/media/screenshots/df7/df77682629ccca6577917c176152d65d.jpg'},
#    {'id': 3628718,
#     'image': 'https://media.rawg.io/media/screenshots/df5/df50fe4e2ef3e97dddf5c8369e3d627d.jpg'},
#    {'id': 3628719,
#     'image': 'https://media.rawg.io/media/screenshots/74d/74d20827f572f5c524b9047c53be0045.jpg'},
#    {'id': 3628720,
#     'image': 'https://media.rawg.io/media/screenshots/a48/a483e91d4b258c65790b12ec2695ce73.jpg'},
#    {'id': 3628721,
#     'image': 'https://media.rawg.io/media/screenshots/6b4/6b4d7903d0e0e44321bd855dc6d61db3.jpg'},
#    {'id': 3628722,
#     'image': 'https://media.rawg.io/media/screenshots/df7/df77682629ccca6577917c176152d65d.jpg'}]}]

# %%
json.dumps(r)
# Out:
# '[{"id": 892902, "slug": "armored-core-vi-fires-of-rubicon", "name": "ARMORED CORE VI FIRES OF RUBICON", "released": null, "tba": true, "background_image": "https://media.rawg.io/media/games/b59/b59f7aa35d656cb35f8fe534878ef536.jpg", "rating": 0.0, "rating_top": 0, "ratings": [], "ratings_count": 0, "reviews_text_count": 0, "added": 1, "added_by_status": {"toplay": 1}, "metacritic": null, "playtime": 0, "suggestions_count": 329, "updated": "2022-12-10T20:47:25", "user_game": null, "reviews_count": 0, "community_rating": 0, "saturated_color": "0f0f0f", "dominant_color": "0f0f0f", "platforms": [{"platform": {"id": 186, "name": "Xbox Series S/X", "slug": "xbox-series-x", "image": null, "year_end": null, "year_start": 2020, "games_count": 678, "image_background": "https://media.rawg.io/media/games/dcb/dcbb67f371a9a28ea38ffd73ee0f53f3.jpg"}, "released_at": null, "requirements_en": null, "requirements_ru": null}, {"platform": {"id": 1, "name": "Xbox One", "slug": "xbox-one", "image": null, "year_end": null, "year_start": null, "games_count": 5453, "image_background": "https://media.rawg.io/media/games/960/960b601d9541cec776c5fa42a00bf6c4.jpg"}, "released_at": null, "requirements_en": null, "requirements_ru": null}, {"platform": {"id": 18, "name": "PlayStation 4", "slug": "playstation4", "image": null, "year_end": null, "year_start": null, "games_count": 6536, "image_background": "https://media.rawg.io/media/games/562/562553814dd54e001a541e4ee83a591c.jpg"}, "released_at": null, "requirements_en": null, "requirements_ru": null}, {"platform": {"id": 187, "name": "PlayStation 5", "slug": "playstation5", "image": null, "year_end": null, "year_start": 2020, "games_count": 754, "image_background": "https://media.rawg.io/media/games/9f1/9f1891779cb20f44de93cef33b067e50.jpg"}, "released_at": null, "requirements_en": null, "requirements_ru": null}, {"platform": {"id": 4, "name": "PC", "slug": "pc", "image": null, "year_end": null, "year_start": null, "games_count": 507022, "image_background": "https://media.rawg.io/media/games/736/73619bd336c894d6941d926bfd563946.jpg"}, "released_at": null, "requirements_en": null, "requirements_ru": null}], "parent_platforms": [{"platform": {"id": 1, "name": "PC", "slug": "pc"}}, {"platform": {"id": 2, "name": "PlayStation", "slug": "playstation"}}, {"platform": {"id": 3, "name": "Xbox", "slug": "xbox"}}], "genres": [{"id": 4, "name": "Action", "slug": "action", "games_count": 169068, "image_background": "https://media.rawg.io/media/games/f87/f87457e8347484033cb34cde6101d08d.jpg"}], "stores": [{"id": 890899, "store": {"id": 1, "name": "Steam", "slug": "steam", "domain": "store.steampowered.com", "games_count": 69983, "image_background": "https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg"}}], "clip": null, "tags": [], "esrb_rating": null, "short_screenshots": [{"id": -1, "image": "https://media.rawg.io/media/games/b59/b59f7aa35d656cb35f8fe534878ef536.jpg"}, {"id": 3685631, "image": "https://media.rawg.io/media/screenshots/a0a/a0a387a199dd4f068c41b9ff9b67eaad.jpg"}, {"id": 3685632, "image": "https://media.rawg.io/media/screenshots/07a/07af4811a071a6cc0a47984e67189915.jpg"}, {"id": 3685633, "image": "https://media.rawg.io/media/screenshots/7f4/7f40bcd98bc68af1c891e0b535e4ad37.jpg"}, {"id": 3685634, "image": "https://media.rawg.io/media/screenshots/6c3/6c3b1709ee0e6d107fa71c0201e3c4a5_zVaxnHT.jpg"}, {"id": 3685635, "image": "https://media.rawg.io/media/screenshots/5e9/5e94d6e326cf5f80d805822c0bb8b774.jpg"}, {"id": 3685636, "image": "https://media.rawg.io/media/screenshots/7b4/7b494af1dc595a3db2b51020fb5f4d05.jpg"}]}, {"id": 892901, "slug": "immortals-of-aveum", "name": "Immortals of Aveum", "released": null, "tba": true, "background_image": null, "rating": 0.0, "rating_top": 0, "ratings": [], "ratings_count": 0, "reviews_text_count": 0, "added": 1, "added_by_status": {"toplay": 1}, "metacritic": null, "playtime": 0, "suggestions_count": 0, "updated": "2022-12-10T20:37:33", "user_game": n ...
